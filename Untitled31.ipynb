# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.models as models
from torch.utils.data import DataLoader

# Check GPU availability
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# Define image transforms
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Load dataset
train_data = datasets.ImageFolder(
    root="C:\\Users\\jasho\\OneDrive\\Desktop\\Lung Disease Dataset\\train",
    transform=transform
)
val_data = datasets.ImageFolder(
    root="C:\\Users\\jasho\\OneDrive\\Desktop\\Lung Disease Dataset\\val",
    transform=transform
)

print("Detected classes:", train_data.classes)  # ['NORMAL', 'PNEUMONIA']

# Data loaders
train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data, batch_size=32, shuffle=False)

ensemble_size = 3  # Number of models in the ensemble

# Model selection for the ensemble
model_choices = [
    models.resnet50(weights=models.ResNet50_Weights.IMAGENET1K_V1),  # ResNet-50
    models.densenet121(weights=models.DenseNet121_Weights.IMAGENET1K_V1),  # DenseNet
    models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.IMAGENET1K_V1)  # EfficientNet
]

for model_idx in range(ensemble_size):
    print(f"\nTraining model {model_idx+1} of {ensemble_size}")
    
    # Select model based on index
    model = model_choices[model_idx]
    
    # Modify the final fully connected layer to match the number of classes in your dataset
    if isinstance(model, models.ResNet):
        num_ftrs = model.fc.in_features
        model.fc = nn.Linear(num_ftrs, len(train_data.classes))
    elif isinstance(model, models.DenseNet):
        num_ftrs = model.classifier.in_features
        model.classifier = nn.Linear(num_ftrs, len(train_data.classes))
    elif isinstance(model, models.EfficientNet):
        num_ftrs = model.classifier[1].in_features
        model.classifier[1] = nn.Linear(num_ftrs, len(train_data.classes))
    
    model = model.to(device)
    
    # Loss and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    
    # Training loop with checkpointing
    epochs = 50  # Adjust as needed
    best_accuracy = 0.0  # For tracking the best validation accuracy
    
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        avg_loss = running_loss / len(train_loader)
        print(f"\nEpoch {epoch+1}/{epochs}")
        print(f"Training Loss: {avg_loss:.4f}")

        # Validation phase
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for val_images, val_labels in val_loader:
                val_images, val_labels = val_images.to(device), val_labels.to(device)
                val_outputs = model(val_images)
                _, predicted = torch.max(val_outputs.data, 1)
                total += val_labels.size(0)
                correct += (predicted == val_labels).sum().item()
        
        val_accuracy = 100 * correct / total
        print(f"Validation Accuracy: {val_accuracy:.2f}%")
        
        # Save best model checkpoint for this ensemble member
        if val_accuracy > best_accuracy:
            best_accuracy = val_accuracy
            checkpoint_path = f"best_model_{model_idx+1}.pth"
            torch.save(model.state_dict(), checkpoint_path)
            print(f"Best model updated and saved as {checkpoint_path} with accuracy: {best_accuracy:.2f}%")
    
    # Optionally save the final model as well (if you want to compare last epoch vs best)
    torch.save(model.state_dict(), f"final_model_{model_idx+1}.pth")
    print(f"Final model for ensemble member {model_idx+1} saved.")
# Out:
# Using device: cuda
# Detected classes: ['Bacterial Pneumonia', 'Corona Virus Disease', 'Normal', 'Tuberculosis', 'Viral Pneumonia']
#
# Training model 1 of 3
#
# Epoch 1/50
# Training Loss: 0.6382
# Validation Accuracy: 71.97%
# Best model updated and saved as best_model_1.pth with accuracy: 71.97%
#
# Epoch 2/50
# Training Loss: 0.4515
# Validation Accuracy: 78.08%
# Best model updated and saved as best_model_1.pth with accuracy: 78.08%
#
# Epoch 3/50
# Training Loss: 0.4024
# Validation Accuracy: 81.15%
# Best model updated and saved as best_model_1.pth with accuracy: 81.15%
#
# Epoch 4/50
# Training Loss: 0.3599
# Validation Accuracy: 81.99%
# Best model updated and saved as best_model_1.pth with accuracy: 81.99%
#
# Epoch 5/50
# Training Loss: 0.3295
# Validation Accuracy: 68.90%
#
# Epoch 6/50
# Training Loss: 0.2708
# Validation Accuracy: 76.19%
#
# Epoch 7/50
# Training Loss: 0.2840
# Validation Accuracy: 85.22%
# Best model updated and saved as best_model_1.pth with accuracy: 85.22%
#
# Epoch 8/50
# Training Loss: 0.2571
# Validation Accuracy: 86.46%
# Best model updated and saved as best_model_1.pth with accuracy: 86.46%
#
# Epoch 9/50
# Training Loss: 0.2405
# Validation Accuracy: 78.08%
#
# Epoch 10/50
# Training Loss: 0.2064
# Validation Accuracy: 74.85%
#
# Epoch 11/50
# Training Loss: 0.2281
# Validation Accuracy: 80.70%
#
# Epoch 12/50
# Training Loss: 0.1779
# Validation Accuracy: 85.32%
#
# Epoch 13/50
# Training Loss: 0.1532
# Validation Accuracy: 82.44%
#
# Epoch 14/50
# Training Loss: 0.1714
# Validation Accuracy: 83.73%
#
# Epoch 15/50
# Training Loss: 0.1140
# Validation Accuracy: 82.54%
#
# Epoch 16/50
# Training Loss: 0.1472
# Validation Accuracy: 84.28%
#
# Epoch 17/50
# Training Loss: 0.0798
# Validation Accuracy: 84.67%
#
# Epoch 18/50
# Training Loss: 0.0840
# Validation Accuracy: 83.18%
#
# Epoch 19/50
# Training Loss: 0.1031
# Validation Accuracy: 83.93%
#
# Epoch 20/50
# Training Loss: 0.0579
# Validation Accuracy: 87.00%
# Best model updated and saved as best_model_1.pth with accuracy: 87.00%
#
# Epoch 21/50
# Training Loss: 0.0737
# Validation Accuracy: 84.92%
#
# Epoch 22/50
# Training Loss: 0.0883
# Validation Accuracy: 84.77%
#
# Epoch 23/50
# Training Loss: 0.0283
# Validation Accuracy: 85.62%
#
# Epoch 24/50
# Training Loss: 0.0345
# Validation Accuracy: 86.76%
#
# Epoch 25/50
# Training Loss: 0.0458
# Validation Accuracy: 81.20%
#
# Epoch 26/50
# Training Loss: 0.0822
# Validation Accuracy: 83.18%
#
# Epoch 27/50
# Training Loss: 0.0274
# Validation Accuracy: 85.96%
#
# Epoch 28/50
# Training Loss: 0.0528
# Validation Accuracy: 84.33%
#
# Epoch 29/50
# Training Loss: 0.0525
# Validation Accuracy: 83.23%
#
# Epoch 30/50
# Training Loss: 0.0490
# Validation Accuracy: 86.21%
#
# Epoch 31/50
# Training Loss: 0.0478
# Validation Accuracy: 85.32%
#
# Epoch 32/50
# Training Loss: 0.0336
# Validation Accuracy: 86.90%
#
# Epoch 33/50
# Training Loss: 0.0340
# Validation Accuracy: 85.47%
#
# Epoch 34/50
# Training Loss: 0.0472
# Validation Accuracy: 81.75%
#
# Epoch 35/50
# Training Loss: 0.0625
# Validation Accuracy: 84.77%
#
# Epoch 36/50
# Training Loss: 0.0396
# Validation Accuracy: 85.42%
#
# Epoch 37/50
# Training Loss: 0.0108
# Validation Accuracy: 86.61%
#
# Epoch 38/50
# Training Loss: 0.0090
# Validation Accuracy: 87.20%
# Best model updated and saved as best_model_1.pth with accuracy: 87.20%
#
# Epoch 39/50
# Training Loss: 0.0145
# Validation Accuracy: 82.44%
#
# Epoch 40/50
# Training Loss: 0.0686
# Validation Accuracy: 82.49%
#
# Epoch 41/50
# Training Loss: 0.0371
# Validation Accuracy: 86.21%
#
# Epoch 42/50
# Training Loss: 0.0096
# Validation Accuracy: 86.61%
#
# Epoch 43/50
# Training Loss: 0.0049
# Validation Accuracy: 87.60%
# Best model updated and saved as best_model_1.pth with accuracy: 87.60%
#
# Epoch 44/50
# Training Loss: 0.0019
# Validation Accuracy: 81.25%
#
# Epoch 45/50
# Training Loss: 0.0363
# Validation Accuracy: 84.42%
#
# Epoch 46/50
# Training Loss: 0.0827
# Validation Accuracy: 84.23%
#
# Epoch 47/50
# Training Loss: 0.0502
# Validation Accuracy: 86.31%
#
# Epoch 48/50
# Training Loss: 0.0141
# Validation Accuracy: 86.41%
#
# Epoch 49/50
# Training Loss: 0.0135
# Validation Accuracy: 83.13%
#
# Epoch 50/50
# Training Loss: 0.0272
# Validation Accuracy: 82.39%
# Final model for ensemble member 1 saved.
#
# Training model 2 of 3
#
# Epoch 1/50
# Training Loss: 0.5354
# Validation Accuracy: 77.33%
# Best model updated and saved as best_model_2.pth with accuracy: 77.33%
#
# Epoch 2/50
# Training Loss: 0.3835
# Validation Accuracy: 83.73%
# Best model updated and saved as best_model_2.pth with accuracy: 83.73%
#
# Epoch 3/50
# Training Loss: 0.3528
# Validation Accuracy: 74.65%
#
# Epoch 4/50
# Training Loss: 0.3027
# Validation Accuracy: 84.57%
# Best model updated and saved as best_model_2.pth with accuracy: 84.57%
#
# Epoch 5/50
# Training Loss: 0.2844
# Validation Accuracy: 81.40%
#
# Epoch 6/50
# Training Loss: 0.2711
# Validation Accuracy: 82.69%
#
# Epoch 7/50
# Training Loss: 0.2395
# Validation Accuracy: 87.40%
# Best model updated and saved as best_model_2.pth with accuracy: 87.40%
#
# Epoch 8/50
# Training Loss: 0.2126
# Validation Accuracy: 85.57%
#
# Epoch 9/50
# Training Loss: 0.2258
# Validation Accuracy: 86.06%
#
# Epoch 10/50
# Training Loss: 0.2187
# Validation Accuracy: 82.19%
#
# Epoch 11/50
# Training Loss: 0.1667
# Validation Accuracy: 82.79%
#
# Epoch 12/50
# Training Loss: 0.1841
# Validation Accuracy: 87.05%
#
# Epoch 13/50
# Training Loss: 0.1464
# Validation Accuracy: 87.10%
#
# Epoch 14/50
# Training Loss: 0.1252
# Validation Accuracy: 85.66%
#
# Epoch 15/50
# Training Loss: 0.2196
# Validation Accuracy: 85.17%
#
# Epoch 16/50
# Training Loss: 0.1113
# Validation Accuracy: 87.50%
# Best model updated and saved as best_model_2.pth with accuracy: 87.50%
#
# Epoch 17/50
# Training Loss: 0.1135
# Validation Accuracy: 87.25%
#
# Epoch 18/50
# Training Loss: 0.0895
# Validation Accuracy: 85.57%
#
# Epoch 19/50
# Training Loss: 0.0896
# Validation Accuracy: 86.95%
#
# Epoch 20/50
# Training Loss: 0.0798
# Validation Accuracy: 86.86%
#
# Epoch 21/50
# Training Loss: 0.0720
# Validation Accuracy: 86.71%
#
# Epoch 22/50
# Training Loss: 0.0563
# Validation Accuracy: 88.05%
# Best model updated and saved as best_model_2.pth with accuracy: 88.05%
#
# Epoch 23/50
# Training Loss: 0.0795
# Validation Accuracy: 87.15%
#
# Epoch 24/50
# Training Loss: 0.0424
# Validation Accuracy: 78.52%
#
# Epoch 25/50
# Training Loss: 0.0809
# Validation Accuracy: 89.09%
# Best model updated and saved as best_model_2.pth with accuracy: 89.09%
#
# Epoch 26/50
# Training Loss: 0.0343
# Validation Accuracy: 87.25%
#
# Epoch 27/50
# Training Loss: 0.0499
# Validation Accuracy: 87.35%
#
# Epoch 28/50
# Training Loss: 0.0711
# Validation Accuracy: 86.06%
#
# Epoch 29/50
# Training Loss: 0.0525
# Validation Accuracy: 88.05%
#
# Epoch 30/50
# Training Loss: 0.0649
# Validation Accuracy: 82.34%
#
# Epoch 31/50
# Training Loss: 0.0260
# Validation Accuracy: 88.49%
#
# Epoch 32/50
# Training Loss: 0.0392
# Validation Accuracy: 86.41%
#
# Epoch 33/50
# Training Loss: 0.0589
# Validation Accuracy: 88.10%
#
# Epoch 34/50
# Training Loss: 0.0377
# Validation Accuracy: 84.13%
#
# Epoch 35/50
# Training Loss: 0.0341
# Validation Accuracy: 86.41%
#
# Epoch 36/50
# Training Loss: 0.0688
# Validation Accuracy: 88.44%
#
# Epoch 37/50
# Training Loss: 0.0388
# Validation Accuracy: 88.49%
#
# Epoch 38/50
# Training Loss: 0.0195
# Validation Accuracy: 88.49%
#
# Epoch 39/50
# Training Loss: 0.0127
# Validation Accuracy: 88.64%
#
# Epoch 40/50
# Training Loss: 0.0439
# Validation Accuracy: 86.86%
#
# Epoch 41/50
# Training Loss: 0.0397
# Validation Accuracy: 86.66%
#
# Epoch 42/50
# Training Loss: 0.0628
# Validation Accuracy: 87.65%
#
# Epoch 43/50
# Training Loss: 0.0192
# Validation Accuracy: 85.96%
#
# Epoch 44/50
# Training Loss: 0.0100
# Validation Accuracy: 88.84%
#
# Epoch 45/50
# Training Loss: 0.0240
# Validation Accuracy: 87.60%
#
# Epoch 46/50
# Training Loss: 0.0128
# Validation Accuracy: 86.95%
#
# Epoch 47/50
# Training Loss: 0.0616
# Validation Accuracy: 84.42%
#
# Epoch 48/50
# Training Loss: 0.0524
# Validation Accuracy: 85.12%
#
# Epoch 49/50
# Training Loss: 0.0291
# Validation Accuracy: 87.70%
#
# Epoch 50/50
# Training Loss: 0.0077
# Validation Accuracy: 88.84%
# Final model for ensemble member 2 saved.
#
# Training model 3 of 3
#
# Epoch 1/50
# Training Loss: 0.4513
# Validation Accuracy: 82.29%
# Best model updated and saved as best_model_3.pth with accuracy: 82.29%
#
# Epoch 2/50
# Training Loss: 0.2876
# Validation Accuracy: 85.12%
# Best model updated and saved as best_model_3.pth with accuracy: 85.12%
#
# Epoch 3/50
# Training Loss: 0.2332
# Validation Accuracy: 88.94%
# Best model updated and saved as best_model_3.pth with accuracy: 88.94%
#
# Epoch 4/50
# Training Loss: 0.2044
# Validation Accuracy: 90.38%
# Best model updated and saved as best_model_3.pth with accuracy: 90.38%
#
# Epoch 5/50
# Training Loss: 0.1798
# Validation Accuracy: 89.78%
#
# Epoch 6/50
# Training Loss: 0.1493
# Validation Accuracy: 89.48%
#
# Epoch 7/50
# Training Loss: 0.1246
# Validation Accuracy: 88.74%
#
# Epoch 8/50
# Training Loss: 0.1028
# Validation Accuracy: 88.74%
#
# Epoch 9/50
# Training Loss: 0.0749
# Validation Accuracy: 88.05%
#
# Epoch 10/50
# Training Loss: 0.1169
# Validation Accuracy: 89.78%
#
# Epoch 11/50
# Training Loss: 0.0906
# Validation Accuracy: 89.78%
#
# Epoch 12/50
# Training Loss: 0.0584
# Validation Accuracy: 88.99%
#
# Epoch 13/50
# Training Loss: 0.0745
# Validation Accuracy: 88.19%
#
# Epoch 14/50
# Training Loss: 0.0410
# Validation Accuracy: 89.73%
#
# Epoch 15/50
# Training Loss: 0.0399
# Validation Accuracy: 87.60%
#
# Epoch 16/50
# Training Loss: 0.0490
# Validation Accuracy: 89.63%
#
# Epoch 17/50
# Training Loss: 0.0595
# Validation Accuracy: 89.38%
#
# Epoch 18/50
# Training Loss: 0.0562
# Validation Accuracy: 87.70%
#
# Epoch 19/50
# Training Loss: 0.0349
# Validation Accuracy: 89.73%
#
# Epoch 20/50
# Training Loss: 0.0226
# Validation Accuracy: 90.23%
#
# Epoch 21/50
# Training Loss: 0.0783
# Validation Accuracy: 87.80%
#
# Epoch 22/50
# Training Loss: 0.0421
# Validation Accuracy: 89.24%
#
# Epoch 23/50
# Training Loss: 0.0293
# Validation Accuracy: 88.34%
#
# Epoch 24/50
# Training Loss: 0.0152
# Validation Accuracy: 90.58%
# Best model updated and saved as best_model_3.pth with accuracy: 90.58%
#
# Epoch 25/50
# Training Loss: 0.0202
# Validation Accuracy: 90.38%
#
# Epoch 26/50
# Training Loss: 0.0287
# Validation Accuracy: 89.63%
#
# Epoch 27/50
# Training Loss: 0.0634
# Validation Accuracy: 90.33%
#
# Epoch 28/50
# Training Loss: 0.0209
# Validation Accuracy: 89.73%
#
# Epoch 29/50
# Training Loss: 0.0187
# Validation Accuracy: 90.08%
#
# Epoch 30/50
# Training Loss: 0.0182
# Validation Accuracy: 89.19%
#
# Epoch 31/50
# Training Loss: 0.0635
# Validation Accuracy: 88.19%
#
# Epoch 32/50
# Training Loss: 0.0529
# Validation Accuracy: 90.97%
# Best model updated and saved as best_model_3.pth with accuracy: 90.97%
#
# Epoch 33/50
# Training Loss: 0.0202
# Validation Accuracy: 90.13%
#
# Epoch 34/50
# Training Loss: 0.0275
# Validation Accuracy: 90.03%
#
# Epoch 35/50
# Training Loss: 0.0215
# Validation Accuracy: 90.58%
#
# Epoch 36/50
# Training Loss: 0.0211
# Validation Accuracy: 90.08%
#
# Epoch 37/50
# Training Loss: 0.0103
# Validation Accuracy: 90.28%
#
# Epoch 38/50
# Training Loss: 0.0255
# Validation Accuracy: 90.33%
#
# Epoch 39/50
# Training Loss: 0.0377
# Validation Accuracy: 90.53%
#
# Epoch 40/50
# Training Loss: 0.0359
# Validation Accuracy: 89.68%
#
# Epoch 41/50
# Training Loss: 0.0415
# Validation Accuracy: 90.53%
#
# Epoch 42/50
# Training Loss: 0.0300
# Validation Accuracy: 88.89%
#
# Epoch 43/50
# Training Loss: 0.0160
# Validation Accuracy: 89.78%
#
# Epoch 44/50
# Training Loss: 0.0438
# Validation Accuracy: 89.38%
#
# Epoch 45/50
# Training Loss: 0.0217
# Validation Accuracy: 88.99%
#
# Epoch 46/50
# Training Loss: 0.0208
# Validation Accuracy: 89.78%
#
# Epoch 47/50
# Training Loss: 0.0124
# Validation Accuracy: 89.93%
#
# Epoch 48/50
# Training Loss: 0.0179
# Validation Accuracy: 89.29%
#
# Epoch 49/50
# Training Loss: 0.0373
# Validation Accuracy: 89.58%
#
# Epoch 50/50
# Training Loss: 0.0126
# Validation Accuracy: 89.68%
# Final model for ensemble member 3 saved.

# %%
import torch
import torch.nn.functional as F
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.models as models

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define transformations
transform_val = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Load validation dataset
val_dataset = ImageFolder(
    root="C:\\Users\\jasho\\OneDrive\\Desktop\\Lung Disease Dataset\\val",
    transform=transform_val
)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Print number of classes in the validation dataset
print("Classes:", val_dataset.classes)
print("Number of classes:", len(val_dataset.classes))

# Load trained model
model = models.resnet50()
num_ftrs = model.fc.in_features
model.fc = torch.nn.Linear(num_ftrs, 5)  # Set this to 5 to match the number of classes
model.load_state_dict(torch.load("best_model_1.pth", map_location=device, weights_only=True))
model = model.to(device)
model.eval()

# Evaluate on validation data
y_true = []
y_pred = []

with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        probs = F.softmax(outputs, dim=1)  # Softmax for multi-class
        _, predicted = torch.max(probs, 1)  # Predicted class
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())

# Compute metrics
acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average='macro', zero_division=0)
rec = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1 = f1_score(y_true, y_pred, average='macro', zero_division=0)
cm = confusion_matrix(y_true, y_pred)

# Output results
print("Accuracy:", acc)
print("Precision (macro):", prec)
print("Recall (macro):", rec)
print("F1 Score (macro):", f1)
print("Confusion Matrix:\n", cm)
# Out:
# Classes: ['Bacterial Pneumonia', 'Corona Virus Disease', 'Normal', 'Tuberculosis', 'Viral Pneumonia']
# Number of classes: 5
# Accuracy: 0.8759920634920635
# Precision (macro): 0.8728246134581964
# Recall (macro): 0.8754531764845661
# F1 Score (macro): 0.8735389925433834
# Confusion Matrix:
#  [[300   3  10   3  85]
#  [  0 386   1  19   0]
#  [  4   1 387   0  10]
#  [  0   0   0 406   0]
#  [ 75   6  33   0 287]]

# %%
import torch
import torch.nn.functional as F
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torchvision.models as models
from torch import nn

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define transformations
transform_val = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Load validation dataset
val_dataset = ImageFolder(
    root="C:\\Users\\jasho\\OneDrive\\Desktop\\Lung Disease Dataset\\val",
    transform=transform_val
)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Load trained model (DenseNet121 in this case)
model = models.densenet121(weights=None)  # Initialize the DenseNet model
num_ftrs = model.classifier.in_features

# Set the classifier to have 5 output classes (update to 5 based on your trained model)
model.classifier = nn.Linear(num_ftrs, 5)  # Assuming the model was trained on 5 classes

# Load the trained model's weights (ensure the model was trained on 5 classes)
model.load_state_dict(torch.load("best_model_2.pth", map_location=device, weights_only=True))
model = model.to(device)
model.eval()

# Evaluate on validation data
y_true = []
y_pred = []

with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        probs = F.softmax(outputs, dim=1)  # Softmax for multi-class
        _, predicted = torch.max(probs, 1)  # Predicted class
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())

# Compute metrics
acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average='macro')
rec = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')
cm = confusion_matrix(y_true, y_pred)

# Output results
print("Accuracy:", acc)
print("Precision (macro):", prec)
print("Recall (macro):", rec)
print("F1 Score (macro):", f1)
print("Confusion Matrix:\n", cm)
# Out:
# Accuracy: 0.8908730158730159
# Precision (macro): 0.887914498610663
# Recall (macro): 0.8903776145255566
# F1 Score (macro): 0.8887603442575344
# Confusion Matrix:
#  [[319   0   4   0  78]
#  [  0 398   0   7   1]
#  [  0   3 393   0   6]
#  [  0   7   0 399   0]
#  [ 79   5  29   1 287]]

# %%
import torch
import torch.nn.functional as F
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchvision import models
from torch import nn

# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define transformations
transform_val = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Load validation dataset
val_dataset = ImageFolder(
    root="C:\\Users\\jasho\\OneDrive\\Desktop\\Lung Disease Dataset\\val",
    transform=transform_val
)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Load EfficientNet model (example with EfficientNet-B0)
model = models.efficientnet_b0(weights=None)  # Change to appropriate EfficientNet variant if needed
num_ftrs = model.classifier[1].in_features
model.classifier[1] = nn.Linear(num_ftrs, 5)  # Assuming the model was trained on 5 classes

# Load the trained model's weights
model.load_state_dict(torch.load("best_model_3.pth", map_location=device, weights_only=True), strict=False)
model = model.to(device)
model.eval()

# Evaluate on validation data
y_true = []
y_pred = []

with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        probs = F.softmax(outputs, dim=1)
        _, predicted = torch.max(probs, 1)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(predicted.cpu().numpy())

# Compute metrics
acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred, average='macro', zero_division=0)  # Handle undefined precision
rec = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1 = f1_score(y_true, y_pred, average='macro', zero_division=0)
cm = confusion_matrix(y_true, y_pred)

# Output results
print("Accuracy:", acc)
print("Precision (macro):", prec)
print("Recall (macro):", rec)
print("F1 Score (macro):", f1)
print("Confusion Matrix:\n", cm)
# Out:
# Accuracy: 0.9052579365079365
# Precision (macro): 0.9047996637297784
# Recall (macro): 0.9048562208428882
# F1 Score (macro): 0.9042740812901549
# Confusion Matrix:
#  [[341   0   5   0  55]
#  [  1 398   1   6   0]
#  [  1   1 391   0   9]
#  [  1   2   1 397   5]
#  [ 84   0  19   0 298]]

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import torchvision.models as models
import torchvision.transforms as transforms

from lime import lime_image
from skimage.segmentation import mark_boundaries

from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load ensemble models for explanation
model_1 = models.resnet50(weights=None)
model_1.fc = torch.nn.Linear(model_1.fc.in_features, 5)
model_1.load_state_dict(torch.load("best_model_1.pth", map_location=device, weights_only=True))
model_1 = model_1.to(device)
model_1.eval()

model_2 = models.densenet121(weights=None)
model_2.classifier = torch.nn.Linear(model_2.classifier.in_features, 5)
model_2.load_state_dict(torch.load("best_model_2.pth", map_location=device, weights_only=True))
model_2 = model_2.to(device)
model_2.eval()

model_3 = models.efficientnet_b0(weights=None)
model_3.classifier[1] = torch.nn.Linear(model_3.classifier[1].in_features, 5)
model_3.load_state_dict(torch.load("best_model_3.pth", map_location=device, weights_only=True))
model_3 = model_3.to(device)
model_3.eval()

ensemble_models = [model_1, model_2, model_3]

# Image transform
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Load image
image_path = "C:\\Users\\jasho\\OneDrive\\Desktop\\Lung Disease Dataset\\test\\Corona Virus Disease\\_31_5818302.jpeg"
image_pil = Image.open(image_path).convert("RGB")
input_tensor = transform(image_pil).unsqueeze(0).to(device)

# Get predicted class from ensemble
with torch.no_grad():
    outputs = [model(input_tensor) for model in ensemble_models]
    avg_logits = torch.mean(torch.stack(outputs), dim=0)
    predicted_class = int(torch.argmax(avg_logits, dim=1).item())

print(f"Predicted class: {predicted_class}")

# LIME: Batch prediction
def batch_predict(images_np):
    batch = torch.stack([
        transform(Image.fromarray(img).convert("RGB")) for img in images_np
    ], dim=0).to(device)

    with torch.no_grad():
        outputs = [model(batch) for model in ensemble_models]
        logits = torch.mean(torch.stack(outputs), dim=0)
    return logits.cpu().numpy()

# LIME Explanation
def get_lime_explanation(pil_img, target_class):
    explainer = lime_image.LimeImageExplainer()
    img_np = np.array(pil_img)

    explanation = explainer.explain_instance(
        img_np,
        batch_predict,
        labels=(target_class,),
        top_labels=2,
        hide_color=0,
        num_samples=1000
    )

    if target_class not in explanation.local_exp:
        raise ValueError(f"Target class {target_class} not found in LIME explanation.")

    lime_img, mask = explanation.get_image_and_mask(
        label=target_class,
        positive_only=True,
        num_features=10,
        hide_rest=False
    )
    return lime_img, mask

# Grad-CAM Explanation (using ResNet50)
def get_gradcam_overlay(input_tensor, image_pil, target_class):
    model_for_cam = model_1
    target_layers = [model_for_cam.layer4[-1]]

    cam = GradCAM(model=model_for_cam, target_layers=target_layers)

    grayscale_cam = cam(input_tensor=input_tensor, targets=[ClassifierOutputTarget(target_class)])[0]

    img_np = np.array(image_pil.resize((224, 224))).astype(np.float32) / 255.0
    if img_np.shape[-1] == 4:
        img_np = img_np[..., :3]

    return show_cam_on_image(img_np, grayscale_cam, use_rgb=True)

# Generate explanations
lime_img, lime_mask = get_lime_explanation(image_pil, predicted_class)
gradcam_img = get_gradcam_overlay(input_tensor, image_pil, predicted_class)

# Display
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].imshow(np.array(image_pil))
axs[0].set_title("Original X-ray")
axs[0].axis("off")

axs[1].imshow(mark_boundaries(lime_img / 255.0, lime_mask))
axs[1].set_title("LIME Explanation")
axs[1].axis("off")

axs[2].imshow(gradcam_img)
axs[2].set_title("Grad-CAM Explanation (ResNet50)")
axs[2].axis("off")

plt.tight_layout()
plt.savefig("lime_gradcam_comparison.png")
plt.show()
# Out:
# Predicted class: 1
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import torchvision.models as models
import torchvision.transforms as transforms

from lime import lime_image
from skimage.segmentation import mark_boundaries

from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load ensemble models for explanation
model_1 = models.resnet50(weights=None)
model_1.fc = torch.nn.Linear(model_1.fc.in_features, 5)
model_1.load_state_dict(torch.load("best_model_1.pth", map_location=device, weights_only=True))
model_1 = model_1.to(device)
model_1.eval()

model_2 = models.densenet121(weights=None)
model_2.classifier = torch.nn.Linear(model_2.classifier.in_features, 5)
model_2.load_state_dict(torch.load("best_model_2.pth", map_location=device, weights_only=True))
model_2 = model_2.to(device)
model_2.eval()

model_3 = models.efficientnet_b0(weights=None)
model_3.classifier[1] = torch.nn.Linear(model_3.classifier[1].in_features, 5)
model_3.load_state_dict(torch.load("best_model_3.pth", map_location=device, weights_only=True))
model_3 = model_3.to(device)
model_3.eval()

ensemble_models = [model_1, model_2, model_3]

# Image transform
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Load image
image_path = "C:\\Users\\jasho\\OneDrive\\Desktop\\Lung Disease Dataset\\test\\Tuberculosis\\test_0_246.jpeg"
image_pil = Image.open(image_path).convert("RGB")
input_tensor = transform(image_pil).unsqueeze(0).to(device)

# Get predicted class from ensemble
with torch.no_grad():
    outputs = [model(input_tensor) for model in ensemble_models]
    avg_logits = torch.mean(torch.stack(outputs), dim=0)
    predicted_class = int(torch.argmax(avg_logits, dim=1).item())

print(f"Predicted class: {predicted_class}")

# LIME: Batch prediction
def batch_predict(images_np):
    batch = torch.stack([
        transform(Image.fromarray(img).convert("RGB")) for img in images_np
    ], dim=0).to(device)

    with torch.no_grad():
        outputs = [model(batch) for model in ensemble_models]
        logits = torch.mean(torch.stack(outputs), dim=0)
    return logits.cpu().numpy()

# LIME Explanation
def get_lime_explanation(pil_img, target_class):
    explainer = lime_image.LimeImageExplainer()
    img_np = np.array(pil_img)

    explanation = explainer.explain_instance(
        img_np,
        batch_predict,
        labels=(target_class,),
        top_labels=2,
        hide_color=0,
        num_samples=1000
    )

    if target_class not in explanation.local_exp:
        raise ValueError(f"Target class {target_class} not found in LIME explanation.")

    lime_img, mask = explanation.get_image_and_mask(
        label=target_class,
        positive_only=True,
        num_features=10,
        hide_rest=False
    )
    return lime_img, mask

# Grad-CAM Explanation (using ResNet50)
def get_gradcam_overlay(input_tensor, image_pil, target_class):
    model_for_cam = model_1
    target_layers = [model_for_cam.layer4[-1]]

    cam = GradCAM(model=model_for_cam, target_layers=target_layers)

    grayscale_cam = cam(input_tensor=input_tensor, targets=[ClassifierOutputTarget(target_class)])[0]

    img_np = np.array(image_pil.resize((224, 224))).astype(np.float32) / 255.0
    if img_np.shape[-1] == 4:
        img_np = img_np[..., :3]

    return show_cam_on_image(img_np, grayscale_cam, use_rgb=True)

# Generate explanations
lime_img, lime_mask = get_lime_explanation(image_pil, predicted_class)
gradcam_img = get_gradcam_overlay(input_tensor, image_pil, predicted_class)

# Display
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].imshow(np.array(image_pil))
axs[0].set_title("Original X-ray")
axs[0].axis("off")

axs[1].imshow(mark_boundaries(lime_img / 255.0, lime_mask))
axs[1].set_title("LIME Explanation")
axs[1].axis("off")

axs[2].imshow(gradcam_img)
axs[2].set_title("Grad-CAM Explanation (ResNet50)")
axs[2].axis("off")

plt.tight_layout()
plt.savefig("lime_gradcam_comparison.png")
plt.show()
# Out:
# Predicted class: 3
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import torchvision.models as models
import torchvision.transforms as transforms

from lime import lime_image
from skimage.segmentation import mark_boundaries

from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load ensemble models for explanation
model_1 = models.resnet50(weights=None)
model_1.fc = torch.nn.Linear(model_1.fc.in_features, 5)
model_1.load_state_dict(torch.load("best_model_1.pth", map_location=device, weights_only=True))
model_1 = model_1.to(device)
model_1.eval()

model_2 = models.densenet121(weights=None)
model_2.classifier = torch.nn.Linear(model_2.classifier.in_features, 5)
model_2.load_state_dict(torch.load("best_model_2.pth", map_location=device, weights_only=True))
model_2 = model_2.to(device)
model_2.eval()

model_3 = models.efficientnet_b0(weights=None)
model_3.classifier[1] = torch.nn.Linear(model_3.classifier[1].in_features, 5)
model_3.load_state_dict(torch.load("best_model_3.pth", map_location=device, weights_only=True))
model_3 = model_3.to(device)
model_3.eval()

ensemble_models = [model_1, model_2, model_3]

# Image transform
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Load image
image_path = "C:\\Users\\jasho\\OneDrive\\Desktop\\Lung Disease Dataset\\test\\Bacterial Pneumonia\\96.jpeg"
image_pil = Image.open(image_path).convert("RGB")
input_tensor = transform(image_pil).unsqueeze(0).to(device)

# Get predicted class from ensemble
with torch.no_grad():
    outputs = [model(input_tensor) for model in ensemble_models]
    avg_logits = torch.mean(torch.stack(outputs), dim=0)
    predicted_class = int(torch.argmax(avg_logits, dim=1).item())

print(f"Predicted class: {predicted_class}")

# LIME: Batch prediction
def batch_predict(images_np):
    batch = torch.stack([
        transform(Image.fromarray(img).convert("RGB")) for img in images_np
    ], dim=0).to(device)

    with torch.no_grad():
        outputs = [model(batch) for model in ensemble_models]
        logits = torch.mean(torch.stack(outputs), dim=0)
    return logits.cpu().numpy()

# LIME Explanation
def get_lime_explanation(pil_img, target_class):
    explainer = lime_image.LimeImageExplainer()
    img_np = np.array(pil_img)

    explanation = explainer.explain_instance(
        img_np,
        batch_predict,
        labels=(target_class,),
        top_labels=2,
        hide_color=0,
        num_samples=1000
    )

    if target_class not in explanation.local_exp:
        raise ValueError(f"Target class {target_class} not found in LIME explanation.")

    lime_img, mask = explanation.get_image_and_mask(
        label=target_class,
        positive_only=True,
        num_features=10,
        hide_rest=False
    )
    return lime_img, mask

# Grad-CAM Explanation (using ResNet50)
def get_gradcam_overlay(input_tensor, image_pil, target_class):
    model_for_cam = model_1
    target_layers = [model_for_cam.layer4[-1]]

    cam = GradCAM(model=model_for_cam, target_layers=target_layers)

    grayscale_cam = cam(input_tensor=input_tensor, targets=[ClassifierOutputTarget(target_class)])[0]

    img_np = np.array(image_pil.resize((224, 224))).astype(np.float32) / 255.0
    if img_np.shape[-1] == 4:
        img_np = img_np[..., :3]

    return show_cam_on_image(img_np, grayscale_cam, use_rgb=True)

# Generate explanations
lime_img, lime_mask = get_lime_explanation(image_pil, predicted_class)
gradcam_img = get_gradcam_overlay(input_tensor, image_pil, predicted_class)

# Display
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].imshow(np.array(image_pil))
axs[0].set_title("Original X-ray")
axs[0].axis("off")

axs[1].imshow(mark_boundaries(lime_img / 255.0, lime_mask))
axs[1].set_title("LIME Explanation")
axs[1].axis("off")

axs[2].imshow(gradcam_img)
axs[2].set_title("Grad-CAM Explanation (ResNet50)")
axs[2].axis("off")

plt.tight_layout()
plt.savefig("lime_gradcam_comparison.png")
plt.show()
# Out:
# Predicted class: 0
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
import os
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader

# Define paths
test_path = "C:\\Users\\jasho\\OneDrive\\Desktop\\Lung Disease Dataset\\test"

# Load test dataset
test_dataset = ImageFolder(root=test_path, transform=transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Load all models in evaluation mode
model_1 = models.resnet50(weights=None)
model_1.fc = torch.nn.Linear(model_1.fc.in_features, len(test_dataset.classes))
model_1.load_state_dict(torch.load("best_model_1.pth", map_location=device, weights_only=True))
model_1.to(device).eval()

model_2 = models.densenet121(weights=None)
model_2.classifier = torch.nn.Linear(model_2.classifier.in_features, len(test_dataset.classes))
model_2.load_state_dict(torch.load("best_model_2.pth", map_location=device, weights_only=True))
model_2.to(device).eval()

model_3 = models.efficientnet_b0(weights=None)
model_3.classifier[1] = torch.nn.Linear(model_3.classifier[1].in_features, len(test_dataset.classes))
model_3.load_state_dict(torch.load("best_model_3.pth", map_location=device, weights_only=True))
model_3.to(device).eval()

ensemble_models = [model_1, model_2, model_3]

# Evaluation
correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)

        # Ensemble prediction
        outputs = [model(images) for model in ensemble_models]
        avg_logits = torch.mean(torch.stack(outputs), dim=0)
        _, predicted = torch.max(avg_logits, dim=1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

test_accuracy = 100 * correct / total
print(f"\nTest Accuracy (Ensemble): {test_accuracy:.2f}%")
# Out:
# Test Accuracy (Ensemble): 90.32%

# %%
from sklearn.metrics import classification_report

all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        outputs = [model(images) for model in ensemble_models]
        avg_logits = torch.mean(torch.stack(outputs), dim=0)
        _, predicted = torch.max(avg_logits, dim=1)

        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.numpy())

print(classification_report(all_labels, all_preds, target_names=test_dataset.classes))
# Out:
#                       precision    recall  f1-score   support
#
#  Bacterial Pneumonia       0.82      0.81      0.81       403
# Corona Virus Disease       0.99      0.98      0.99       407
#               Normal       0.92      0.98      0.95       404
#         Tuberculosis       0.98      1.00      0.99       408
#      Viral Pneumonia       0.80      0.75      0.77       403
#
#             accuracy                           0.90      2025
#            macro avg       0.90      0.90      0.90      2025
#         weighted avg       0.90      0.90      0.90      2025

# %%
import torch
import numpy as np
from PIL import Image
import torchvision.models as models
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import os

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Class names (update if needed)
class_names = ['Bacterial Pneumonia', 'Corona Virus Disease', 'Normal', 'Tuberculosis', 'Viral Pneumonia']

# Image transform - MUST match training
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Clean DataParallel keys
def clean_state_dict(state_dict):
    new_state_dict = {}
    for k, v in state_dict.items():
        if k.startswith("module."):
            new_state_dict[k[7:]] = v
        else:
            new_state_dict[k] = v
    return new_state_dict

# Robust model loading function
def load_model(checkpoint_path):
    # Initialize the ResNet model
    model = models.resnet50(weights=None)
    model.fc = torch.nn.Linear(model.fc.in_features, len(class_names))

    try:
        checkpoint = torch.load(checkpoint_path, map_location=device, weights_only=True)

        if isinstance(checkpoint, dict):
            if 'model_state_dict' in checkpoint:
                state_dict = clean_state_dict(checkpoint['model_state_dict'])
            elif 'state_dict' in checkpoint:
                state_dict = clean_state_dict(checkpoint['state_dict'])
            else:
                state_dict = clean_state_dict(checkpoint)
            model.load_state_dict(state_dict, strict=False)  # Use strict=False to handle missing keys

        else:
            # If entire model was saved (e.g., torch.save(model))
            model = checkpoint

    except Exception as e:
        print(f"❌ Failed to load {checkpoint_path}: {e}")
        raise

    model.to(device)
    model.eval()
    return model

# Load ensemble models
ensemble_paths = ["best_model_1.pth", "best_model_2.pth", "best_model_3.pth"]
ensemble_models = [load_model(path) for path in ensemble_paths]

# Prediction function
def predict_xray(image_path):
    image = Image.open(image_path).convert("RGB")
    input_tensor = transform(image).unsqueeze(0).to(device)

    predictions = []
    with torch.no_grad():
        for model in ensemble_models:
            output = model(input_tensor)
            pred = torch.argmax(output, dim=1).item()
            predictions.append(pred)

    # Majority vote
    final_prediction = max(set(predictions), key=predictions.count)
    label = class_names[final_prediction]

    print(f"\n🧠 Predictions from ensemble: {[class_names[p] for p in predictions]}")
    print(f"✅ Final predicted label (majority vote): {label}")


    return input_tensor, image, final_prediction

# Example test
test_image_path = r"C:\\Users\\jasho\\OneDrive\\Desktop\\Lung Disease Dataset\\test\\Bacterial Pneumonia\\96.jpeg"
input_tensor, original_pil, final_pred = predict_xray(test_image_path)
# Out:
# 🧠 Predictions from ensemble: ['Bacterial Pneumonia', 'Viral Pneumonia', 'Tuberculosis']
# ✅ Final predicted label (majority vote): Bacterial Pneumonia
